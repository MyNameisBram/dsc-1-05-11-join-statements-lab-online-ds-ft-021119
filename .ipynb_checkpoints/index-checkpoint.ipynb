# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge on Join statements.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table we will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, we'll use the same Customer Relationship Management (CRM) database we used in our lecture before!
# <img src='Database-Schema.png' width=550>

# %%
('''select customername, city, state, comments from customers join orders using (customernumber) Where status = 'cancelled'   ;''')

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
import sqlite3 as sq 
import pandas as pd

#why do we need ... detect_types=sqlite3.PARSE_COLNAMES) ?
connection = sq.connect('data.sqlite', detect_types=sq.PARSE_COLNAMES)
cur = connection.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.

# %%
cur.execute('''SELECT FirstName, LastName FROM employees JOIN offices USING(officeCode) WHERE city = 'Boston'; ''')
cur.fetchall()
# Out:
# [('Julie', 'Firrelli'), ('Steve', 'Patterson')]

# %%
cur.execute('''SELECT FirstName, LastName FROM employees JOIN offices USING(officeCode) WHERE city = 'Boston'; ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   firstName   lastName
# 0     Julie   Firrelli
# 1     Steve  Patterson

# %% [markdown]
# ## Do any offices have no employees?

# %%
cur.execute("""select city, count(*)from offices left join employees using(officeCode)group by 1;""")
df = pd.DataFrame(cur.fetchall())
df.head()
# Out:
#                0  1
# 0         Boston  2
# 1         London  2
# 2            NYC  2
# 3          Paris  5
# 4  San Francisco  6

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
cur.execute('''select * from orders;''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(5)
# Out:
#   orderNumber   orderDate requiredDate shippedDate   status  \
# 0       10100  2003-01-06   2003-01-13  2003-01-10  Shipped
# 1       10101  2003-01-09   2003-01-18  2003-01-11  Shipped
# 2       10102  2003-01-10   2003-01-18  2003-01-14  Shipped
# 3       10103  2003-01-29   2003-02-07  2003-02-02  Shipped
# 4       10104  2003-01-31   2003-02-09  2003-02-01  Shipped
#
#                  comments customerNumber
# 0                                    363
# 1  Check on availability.            128
# 2                                    181
# 3                                    121
# 4                                    141

# %%
#Select productline and description where the MSRP price is greater than 100.00 

cur.execute('''select productline, textdescription from productlines join products using(productline) where MSRP >= 100; ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(10)
# Out:
#         productLine                                    textDescription
# 0       Motorcycles  Our motorcycles are state of the art replicas ...
# 1      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 2       Motorcycles  Our motorcycles are state of the art replicas ...
# 3       Motorcycles  Our motorcycles are state of the art replicas ...
# 4      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 5      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 6      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 7      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 8  Trucks and Buses  The Truck and Bus models are realistic replica...
# 9       Motorcycles  Our motorcycles are state of the art replicas ...

# %%
#Select customer name, city and comment from customers that cancelled orders.

# %%
cur.execute('''select customername, city, state, comments from customers left join orders using (customernumber) Where status = 'cancelled'   ;''')
# df = pd.DataFrame(cur.fetchall())
# df.columns = [i[0] for i in cur.description]
# df.head(10)
cur.fetchall()
# Out:
# []

# %%
cur.execute('''select * from customers join orders using(customernumber); ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(10)
# Out:
#   customerNumber                customerName contactLastName contactFirstName  \
# 0            103           Atelier graphique         Schmitt          Carine
# 1            103           Atelier graphique         Schmitt          Carine
# 2            103           Atelier graphique         Schmitt          Carine
# 3            112          Signal Gift Stores            King             Jean
# 4            112          Signal Gift Stores            King             Jean
# 5            112          Signal Gift Stores            King             Jean
# 6            114  Australian Collectors, Co.        Ferguson            Peter
# 7            114  Australian Collectors, Co.        Ferguson            Peter
# 8            114  Australian Collectors, Co.        Ferguson            Peter
# 9            114  Australian Collectors, Co.        Ferguson            Peter
#
#           phone       addressLine1 addressLine2       city     state  \
# ...

# %%
cur.execute("""select * from customers join employees on customers.salesRepEmployeeNumber = employees.employeeNumber order by employeeNumber; """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df.head()
# Out:
#   customerNumber                  customerName contactLastName  \
# 0            124  Mini Gifts Distributors Ltd.          Nelson
# 1            129               Mini Wheels Co.          Murphy
# 2            161          Technics Stores Inc.       Hashimoto
# 3            321      Corporate Gift Ideas Co.           Brown
# 4            450     The Sharp Gifts Warehouse           Frick
#
#   contactFirstName       phone               addressLine1 addressLine2  \
# 0            Susan  4155551450            5677 Strong St.
# 1            Julie  6505555787  5557 North Pendale Street
# 2             Juri  6505556809          9408 Furth Circle
# 3            Julie  6505551386            7734 Strong St.
# 4              Sue  4085553659             3086 Ingle Ln.
#
#             city state postalCode    ...     salesRepEmployeeNumber  \
# 0     San Rafael    CA      97562    ...                       1165
# 1  San Francisco    CA      94217    ...                       1165
# ...

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold.

# %%
#select

cur.execute('''select customername, country from payments left join customers using(customernumber) where creditlimit > 100000 ; ''')
df = pd.DataFrame(cur.fetchall())
df.columns = [i[0] for i in cur.description]
df.head(10)
# Out:
#                  customerName    country
# 0           Atelier graphique     France
# 1           Atelier graphique     France
# 2           Atelier graphique     France
# 3          Signal Gift Stores        USA
# 4          Signal Gift Stores        USA
# 5          Signal Gift Stores        USA
# 6  Australian Collectors, Co.  Australia
# 7  Australian Collectors, Co.  Australia
# 8  Australian Collectors, Co.  Australia
# 9  Australian Collectors, Co.  Australia

# %% [markdown]
# ## Level Up: Display the Number of Products each Employee Has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use Join statements, along with leveraging your foreign keys knowledge!
